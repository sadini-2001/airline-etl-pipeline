# %% [markdown]
# **Airline Pipeline — Shared Utilities**
#
# This notebook is called via `%run` by all other notebooks.

# %%
# ── Catalog & Schema names ─────────────────────────────
catalog       = "airline"
bronze_schema = "bronze"
silver_schema = "silver"
gold_schema   = "gold"

# ── S3 Paths ───────────────────────────────────────────
BUCKET         = "bts-air"
landing_path   = f"s3://{BUCKET}/landing/flights/"
processed_path = f"s3://{BUCKET}/processed/flights/"

print(f"Catalog        : {catalog}")
print(f"Landing Path   : {landing_path}")
print(f"Processed Path : {processed_path}")
